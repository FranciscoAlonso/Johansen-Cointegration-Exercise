# %% [markdown]
# # Cointegration Example in Multivariate Time Series
#
# ## Review
#
#
# - Augmented Dickey Fuller test
# - Johansen Test for Cointegration

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.vector_ar.vecm import coint_johansen
from statsmodels.tsa.vector_ar.var_model import VAR
# %pylab inline
pylab.rcParams['figure.figsize'] = (18.0, 8.0)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Generate three series with a normal distribution (0, 1)

# %%
mu = 0
sigma = 1
n = 10000
np.random.seed(42)
s1 = list(np.random.normal(mu, sigma, n))
s2 = np.random.normal(mu, sigma, n)
s3 = np.random.normal(mu, sigma, n)
s4 = np.random.normal(mu, sigma, n)

# %%
s = s1
plt.figure(1)
plt.subplot(121)
plt.plot(s)
plt.subplot(122)
plt.hist(s, 30, normed=True)
plt.show()
# Out:
# C:\Users\686114\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.

# %% [markdown]
# ### Create processes:
#
# $X_{1t} = \sum_{i=1}^t \sum_{j=1}^i \epsilon_{1j} + \sum_{i=1}^t \epsilon_{2i}$
#
# $X_{2t} = a\sum_{i=1}^t \sum_{j=1}^i \epsilon_{1j} + b\sum_{i=1}^t \epsilon_{2i} + \epsilon_{3t}$
#
# $X_{3t} = c\sum_{i=1}^t \epsilon_{2i} + \epsilon_{4t}$
#
# $X_{1t}$ is $I(2)$
#
# $X_{2t}$ is $I(2)$
#
# $X_{3t}$ is $I(1)$

# %%
def sum_range(j, i, x):
    return np.cumsum(list(x[j:i]))

sum_range(0,5, list(range(1, 11)))
# Out:
# array([ 1,  3,  6, 10, 15], dtype=int32)

# %%
def sumofsum(x):
    a = np.array(x)
    for i in range(0, len(x)+1):
        a = np.cumsum(sum_range(0, i, x))
    return a

# %% [markdown]
# Generating the processes and keeping them into a dataframe:

# %%
a = 0.5
b = 0.4
c = 0.3

# [a, -1, 0]
va = [0.5,-1, 0]
# [ac, −c, −(a − b)]
vb = [a*c, -c, -(a-b)]

x_1t = sumofsum(s1) + np.cumsum(s3)
x_2t = a*sumofsum(s1) + b*np.cumsum(s2) + s3
x_3t = c*np.cumsum(s2) + s4

todays_date = datetime.datetime.now().date()
#Create date daily index from 10 days before today until 'n'
index = pd.date_range(todays_date-datetime.timedelta(10), periods=n, freq='D')
y = pd.DataFrame(index=index, data={'col1': x_1t, 'col2': x_2t, 'col3':x_3t} )
y.plot()

# %% [markdown]
# ### Augmented Dickey Fuller test
#
# **Null Hypothesis (H0)**: If failed to be rejected, it suggests the time series has a unit root, meaning it is non-stationary. It has some time dependent structure.
#
# **Alternate Hypothesis (H1)**: The null hypothesis is rejected; it suggests the time series does not have a unit root, meaning it is stationary. It does not have time-dependent structure.

# %%
def ADF(v, crit='5%', max_d=6, reg='nc', autolag='AIC'):
    """ Augmented Dickey Fuller test

    Parameters
    ----------
    v: ndarray matrix

    Returns
    -------
    bool: boolean
        true if v passes the test 
    """

    boolean = False

    adf = adfuller(v, max_d, reg, autolag)

    print(adf[0], '>', adf[4][crit], ' ?')
    if(adf[0] < adf[4][crit]):
        pass
    else:
        boolean = True

    return boolean

# %% [markdown]
# ### Testing Unit root
#
# Seems that all processes are stationary which contradicts the example's assumptions:

# %%
print(ADF(x_1t))   
print(ADF(np.diff(x_1t,1)))
print(ADF(x_2t))
print(ADF(np.diff(x_2t,1)))
print(ADF(x_3t))
# Out:
# -1.3970864860582037 > -1.9410269124810415  ?
# True
# -0.9022599376819164 > -1.9410269124810415  ?
# True
# -1.4254765570489873 > -1.9410269124810415  ?
# True
# -0.8683215711297543 > -1.9410269151778108  ?
# True
# 0.16548017753212774 > -1.9410269124810415  ?
# True

# %% [markdown]
# Going further, plotting the first difference seems to confirm the series $X_{1t}$ and $X_{2t}$ are not stationary contradicting the ADF Test results:

# %%
ydiff = pd.DataFrame(data={'col1diff': np.diff(x_1t,1), 'col2diff': np.diff(x_2t,1), 'col3diff': np.diff(x_3t, 1)})
plot(ydiff['col1diff'])
show(plot)
plot(ydiff['col2diff'])
show(plot)
plot(ydiff['col3diff'])
show(plot)

# %% [markdown]
# The second difference shows a better picture of the series confirming the exercise statement of they being $I(2)$:

# %%
ydiff = pd.DataFrame(data={'col1diff': np.diff(x_1t,2), 'col2diff': np.diff(x_2t,2), 'col3diff': np.diff(x_3t, 2)})
plot(ydiff['col1diff'])
show(plot)
plot(ydiff['col2diff'])
show(plot)
plot(ydiff['col3diff'])
show(plot)

# %% [markdown]
# ### Johansen Function

# %% [markdown]
# Perform Johansen Cointegration Test and check which trace values are over the critical values at 95% confidence interval

# %%
def get_johansen(y, p):
        """
        Get the cointegration vectors at 95% level of significance
        given by the trace statistic test.
        """
        """
        H0: no cointegrating equation -> No cointegrating vectors
        H1: H0 is not true
        """
        N, l = y.shape
        jres = coint_johansen(y, 0, p)
        
        print("Critical values (90%, 95%, 99%) of maximum eigenvalue statistic.: ")
        print(jres.cvm, "\n")
        print("Maximum eigenvalue statistic:")
        print(jres.lr2, "\n")
        
        print("Critical values (90%, 95%, 99%) of trace statistic:")
        print(jres.cvt, "\n")
        print("Trace statistic:")
        print(jres.lr1, "\n")
        
        print("Eigenvalues of VECM coefficient matrix:")
        print(jres.eig, "\n")

        print("Eigenvectors of VECM coefficient matrix:")
        print(jres.evec, "\n")

        print("Test method:")
        print(jres.meth, "\n")

        print("Residuals for ΔY.:")
        print(jres.r0t, "\n")

        print("Residuals for Y−1:")
        print(jres.rkt, "\n")
        
        
        trstat = jres.lr1                       # trace statistic
        tsignf = jres.cvt                       # critical values
        
        """
        IF the trace statistic for each series is greater than the critical value THEN:
        that corresponding eigenvector is a cointegration vector
        """
        for i in range(l):
            if trstat[i] > tsignf[i, 1]:     # 0:90%  1:95%  2:99%
                r = i + 1
        jres.r = r
        jres.evecr = jres.evec[:, :r]

        return jres

# %%
p=1
jres=get_johansen(y,p)
print("There are ", jres.r, "cointegration vectors")
print(jres.evecr)
# Out:
# Critical values (90%, 95%, 99%) of maximum eigenvalue statistic.:
# [[18.8928 21.1314 25.865 ]
#  [12.2971 14.2639 18.52  ]
#  [ 2.7055  3.8415  6.6349]]
#
# Maximum eigenvalue statistic:
# [107.76233098   8.21339932   5.35743802]
#
# Critical values (90%, 95%, 99%) of trace statistic:
# [[27.0669 29.7961 35.4628]
#  [13.4294 15.4943 19.9349]
#  [ 2.7055  3.8415  6.6349]]
#
# Trace statistic:
# [121.33316833  13.57083734   5.35743802]
#
# Eigenvalues of VECM coefficient matrix:
# [0.01072051 0.00082117 0.00053571]
#
# Eigenvectors of VECM coefficient matrix:
# [[ 0.04263181  0.00748355 -0.0177313 ]
#  [-0.08526481 -0.01494122  0.03545848]
#  [ 0.24273352 -0.00665092  0.00452081]]
#
# Test method:
# johansen
#
# Residuals for ΔY.:
# [[-0.69208609 -1.48315939  0.69968893]
#  [ 2.68328877  2.23184206  0.94263737]
#  [-1.86404306 -1.34929476  1.55018811]
#  ...
#  [-2.03197033 -1.92426587  0.17054318]
#  [-1.45621029 -1.07680893  0.99168898]
#  [ 2.37188696  2.36452876 -0.61601773]]
#
# Residuals for Y−1:
# [[-1.89266630e+05 -9.46882393e+04 -1.78984010e+01]
#  [-1.89342256e+05 -9.47268167e+04 -1.74017270e+01]
#  [-1.88104407e+05 -9.41068829e+04 -1.63375442e+01]
#  ...
#  [-2.48368728e+04 -1.23676892e+04  1.85687141e+01]
#  [-2.56545875e+04 -1.27768444e+04  1.83101133e+01]
#  [-2.69644017e+04 -1.34332188e+04  1.83892146e+01]]
#
# There are  3 cointegration vectors
# [[ 0.04263181  0.00748355 -0.0177313 ]
#  [-0.08526481 -0.01494122  0.03545848]
#  [ 0.24273352 -0.00665092  0.00452081]]

# %% [markdown]
# Cointegration vectors are not similar to the espected ones.

# %%
print(va)
print(vb)
# Out:
# [0.5, -1, 0]
# [0.15, -0.3, -0.09999999999999998]

# %%
# The series still seems non-stationary
plot(np.dot(y.as_matrix(), jres.evecr[:,0]))
# Out:
# C:\Users\686114\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:2: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
